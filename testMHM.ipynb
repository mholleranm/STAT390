# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('My_CHI._My_Future._Programs.csv')
display(data)
# Out:
#        Program ID                                       Program Name
# 0          138124  How to Finally Get Consistent with Healthy Eating  \
# 1          121806             English Conversation with Chicago Lawn
# 2          138692  Law at the Library: Changes in Tax Law, Know B...
# 3          121878         Voices for Justice: Author Qian Julie Wang
# 4          121912  Science Fiction & Fantasy Book Group: Dawn by ...
# ...           ...                                                ...
# 68600       90896                           Seasonal Sports at Rowan
# 68601      130341  Trampoline - Sub-Novice - Novice at Morgan Par...
# 68602       98296                  Intro to Hockey at Morgan Park SC
# 68603      112529                     Stick & Puck at Morgan Park SC
# 68604      104051                 Ballet - Youth 2 at Morgan Park SC
#
#                                              Description
# 0      During this workshop youÕll identify the main ...  \
# ...

# %%
data.columns
# Out:
# Index(['Program ID', 'Program Name', 'Description', 'Org Name',
#        'Category Name', 'Capacity', 'Min Age', 'Max Age', 'Address', 'City',
#        'State', 'ZIP Code', 'Program Type', 'Program URL', 'Online Address',
#        'Registration URL', 'Registration Open', 'Registration Deadline',
#        'Start Date', 'End Date', 'Start Time', 'End Time', 'Contact Name',
#        'Contact Email', 'Contact Phone', 'Program Price',
#        'Geographic Cluster Name', 'Scholarship Available', 'Participants Paid',
#        'Transport Provided', 'Has Free Food', 'Meeting Type', 'Image',
#        'Hidden Programs', 'Featured', 'Tag', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
data["Latitude"].min()
data_LL_out = data[data["Latitude"] > 40.5]

# %%
plt.scatter(data_LL_out['Longitude'], data_LL_out['Latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
data['Program Price'].unique()
# Out:
# array(['Free', 'More Than $50', '$50 or Less', 'Unknown'], dtype=object)

# %%
data_LL_unkCost_out = data_LL_out[data_LL_out["Program Price"] != 'Unknown']

# %%
#plt.scatter(data_LL_unkCost_out['Longitude'], data_LL_unkCost_out['Latitude'], s=200, c=data_LL_unkCost_out['Program Price'], cmap='gray')
#plt.xlabel('Longitude')
#plt.ylabel('Latitude')
#plt.show()

groups = data_LL_unkCost_out.groupby('Program Price')
for name, group in groups:
    plt.plot(group.Longitude, group.Latitude, marker='o', linestyle='', markersize=2, label=name)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()

# %%
groups = data_LL_out.groupby('Program Price')
for name, group in groups:
    plt.plot(group.Longitude, group.Latitude, marker='o', linestyle='', markersize=2, label=name)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
